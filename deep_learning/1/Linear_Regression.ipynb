# %% [markdown]
# # Linear Regression on the Housing Prices Dataset
#
# The dataset we have used here pertains to the houses found in a given California district and some summary stats about them based on the 1990 census data.The columns are as follows, their names are self explanitory:
#
# 1. longitude
# 2. latitude
# 3. housing_median_age
# 4. total_rooms
# 5. total_bedrooms
# 6. population
# 7. households
# 8. median_income
# 9. median_house_value
# 10. ocean_proximity

# %% [markdown]
# ## Mount data into Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Import all Libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Flatten, Conv1D, Conv2D, MaxPooling1D, MaxPooling2D, LSTM, Embedding, Dropout
from keras.preprocessing import image
from sklearn.model_selection import RandomizedSearchCV, KFold
from sklearn.metrics import make_scorer
from keras.wrappers.scikit_learn import KerasClassifier

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### 1. Read Dataset

# %%
df=pd.read_csv("drive/MyDrive/housing.csv")
df.head()
# Out:
#    longitude  latitude  ...  median_house_value  ocean_proximity
# 0    -122.23     37.88  ...            452600.0         NEAR BAY
# 1    -122.22     37.86  ...            358500.0         NEAR BAY
# 2    -122.24     37.85  ...            352100.0         NEAR BAY
# 3    -122.25     37.85  ...            341300.0         NEAR BAY
# 4    -122.25     37.85  ...            342200.0         NEAR BAY
#
# [5 rows x 10 columns]

# %% [markdown]
# ### 2. Remove Rows containing Null values
#
# As there are some null elements present in the dataset and the number is very less so we drop them as small number of elements missing from such a big dataset wont make much of a big difference.

# %%
df.dropna(inplace=True)
df.shape
# Out:
# (20433, 10)

# %% [markdown]
# ### 3. Split the dataset into Input and Output values
#
# We now seperate the dataframe into X (the features ) and Y the output variable (Its a value as we are doing regression)

# %%
X=pd.DataFrame(columns=['longitude','latitude','housing_median_age','total_rooms','total_bedrooms','population','households','median_income','ocean_proximity'],data=df)
y=pd.DataFrame(columns=['median_house_value'],data=df)

# %% [markdown]
# ### 4. Substitute Non Numeric Values
#
# If we see the dataset , we can see that the feature ```ocean_proximity``` has non integer values such as ```NEAR BAY``` , ```NEAROCEAN``` , ```INLAND``` , ```ISLAND```
#
# Therefore we convert these fourn into 4 new features with the prefix ocean_proximity attached to the 4 options available.
#
# Value 1 is given if it belongs to that class or else 0 is given to it.

# %%
X = pd.get_dummies(data = X, columns = ['ocean_proximity'] , prefix = ['ocean_proximity'] , drop_first = True)
X.head()
# Out:
#    longitude  latitude  ...  ocean_proximity_NEAR BAY  ocean_proximity_NEAR OCEAN
# 0    -122.23     37.88  ...                         1                           0
# 1    -122.22     37.86  ...                         1                           0
# 2    -122.24     37.85  ...                         1                           0
# 3    -122.25     37.85  ...                         1                           0
# 4    -122.25     37.85  ...                         1                           0
#
# [5 rows x 12 columns]

# %% [markdown]
# ### 5. Normalize Inputs
#
# Since the different features in the inputs might be of different orders, we have to normalize them so that they have an equal chance of influencing our model.
#
# We use SciKit Learn's ```StandardScaler``` to do this.

# %%
scaler = StandardScaler()
scaler.fit_transform(X) # First fit to input data, then transform it
# Out:
# array([[-1.32731375,  1.05171726,  0.98216331, ..., -0.01564487,
#          2.82866074, -0.38418614],
#        [-1.32232256,  1.04235526, -0.60621017, ..., -0.01564487,
#          2.82866074, -0.38418614],
#        [-1.33230494,  1.03767426,  1.85576873, ..., -0.01564487,
#          2.82866074, -0.38418614],
#        ...,
#        [-0.82320322,  1.77727236, -0.92388486, ..., -0.01564487,
#         -0.35352419, -0.38418614],
#        [-0.87311515,  1.77727236, -0.84446619, ..., -0.01564487,
#         -0.35352419, -0.38418614],
#        [-0.83318561,  1.74918635, -1.00330353, ..., -0.01564487,
#         -0.35352419, -0.38418614]])

# %% [markdown]
# ### 6. Adjust Output Scale
#
# Since the ```median_house_value``` is very large, we divide the output by ```100,000``` to obtain output in lakhs. The data becomes easy to visualize.

# %%
y = y / 100000

# %% [markdown]
# ### 7. Split the dataset into Training and Testing datasets
#
# We use SciKit Learn's ```train_test_split``` function to split our dataset into training and testing datasets with a 80/20 split.

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state = 0)

# %%
X_train.shape
# Out:
# (16346, 12)

# %% [markdown]
# ## Training

# %% [markdown]
# ### 1. Create the Model
#
# Now we define our model and use a function ```create_model``` which returns the model to be used in our Random Search Function. The function takes the following inputs
#   - ```nl``` which is the number of layers,
#   - ```nn``` which is an array of the number of neurons in each layer,
#   - ```lr``` which is the learning rate of the, and
#   - ```act``` which is the activation function.
#
#
# We then create ```nl``` hidden layers and the output layer. We use the **RELU Activation** function for the output layer as it is a **Linear Regression Problem**. We use the **Adam Optimizer** to optimize our ANN and use **Mean Squared Error** as our loss function and metric.

# %%
def create_model(nl=1, nn=[1000], lr=0.01,act="relu"):
    opt = keras.optimizers.Adam(lr=lr)                                       
    model = Sequential()
    # for the first layer we need to specify the input dimensions
    first=True
    for i in range(nl):
        if first:
            model.add(Dense(nn[i], activation='relu', input_dim = X.shape[1]))
            first=False
        else: 
            model.add(Dense(nn[i], activation=act))            
    model.add(Dense(1,activation="relu"))
    model.compile(loss='mean_squared_error', optimizer=opt, metrics='mse',)
    return model

# %% [markdown]
# ### 2. Random Search and Training

# %% [markdown]
# #### 2.1 Custom Implementation of Random Search
#
# With exploration and learing in mind, we have used a **custom built random search funtion** instead of using a Random search library. This function performs all the functionalities as ScikitLearn's ```RandomizedSearchCV``` function. We define our Random Function ```getRandom()```.
#
# The function generates the parameters of the model based on the following
# 1. ```nl``` - Uniform Distribution of Integers ```[5, 30]```,
# 2. ```nn``` - Uniform Distribution of Integers ```[16, 1024]```
# 3. ```lr``` - Randomly picked from set ```{0.01, 0.001, 0.0001, 0.00001}```
# 4. ```act``` - relu.
#
# In each iteration we train the created model using Keras' ```model.fit()```. We then evaluate the model against our test dataset and compute the **Mean Square Error** Loss.
#
# After each iteration we return the ```params```, ```model```, and ```mseSum```. These are processed to find the model, and set of params, which minimize the MSE.

# %%
import random

def getRandom() :
  # Number of layers
  nl = random.randint(5,30)

  # Number of neurons per layer
  nn = []
  for i in range(nl) :
    nn.append(random.randint(16,1024))
  
  # Activation function
  act = "relu"

  # Learning Rate
  lr = random.choice([0.01, 0.001,0.0001,0.00001])

  params = [nl, nn, act, lr]

  model = create_model(nl=nl, nn=nn, act="relu", lr=lr)
  model.fit(x=X_train,y=y_train.to_numpy(),epochs=100,verbose=1,batch_size=45)

  #predict and get the mse on the test set
  predy = model.predict(X_test)

  acty = y_test.to_numpy()
  mseSum = 0
  for i in range (predy.size) :
    temp = predy[i]- acty[i][0]
    mseSum =  mseSum + (temp*temp)
  mseSum = mseSum/predy.size

  return params, model, mseSum

# %% [markdown]
# We now initialize lists to store the Randomly Generated models, their params, and their MSE Losses.
#
# We then call ```getRandom()``` a total of ```n = n_iter(20)``` times and store the results of each call.

# %%
modelList = []
paramsList = []
mseSumList = []
finalM = None
n_iter = 20
mseMin = 999999999
for i in range(n_iter) :
  print("Iteration ",i+1)
  params, model, mseSum = getRandom()
  paramsList.append(params)
  modelList.append(model)
  mseSumList.append(mseSum)
# Out:
# Iteration  1
# Epoch 1/100
# 364/364 [==============================] - 3s 6ms/step - loss: 5.6842 - mse: 5.6842
# Epoch 2/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6263 - mse: 5.6263
# Epoch 3/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6489 - mse: 5.6489
# Epoch 4/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6375 - mse: 5.6375
# Epoch 5/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5647 - mse: 5.5647
# Epoch 6/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5453 - mse: 5.5453
# Epoch 7/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6176 - mse: 5.6176
# Epoch 8/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6410 - mse: 5.6410
# Epoch 9/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6542 - mse: 5.6542
# Epoch 10/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6557 - mse: 5.6557
# Epoch 11/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6424 - mse: 5.6424
# Epoch 12/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5806 - mse: 5.5806
# Epoch 13/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5671 - mse: 5.5671
# Epoch 14/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6108 - mse: 5.6108
# Epoch 15/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6175 - mse: 5.6175
# Epoch 16/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6277 - mse: 5.6277
# Epoch 17/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6984 - mse: 5.6984
# Epoch 18/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6275 - mse: 5.6275
# Epoch 19/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6635 - mse: 5.6635
# Epoch 20/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6055 - mse: 5.6055
# Epoch 21/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5923 - mse: 5.5923
# Epoch 22/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5433 - mse: 5.5433
# Epoch 23/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6243 - mse: 5.6244
# Epoch 24/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5928 - mse: 5.5928
# Epoch 25/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6272 - mse: 5.6272
# Epoch 26/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5370 - mse: 5.5370
# Epoch 27/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6449 - mse: 5.6449
# Epoch 28/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6243 - mse: 5.6243
# Epoch 29/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6014 - mse: 5.6014
# Epoch 30/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5655 - mse: 5.5655
# Epoch 31/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6235 - mse: 5.6235
# Epoch 32/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5949 - mse: 5.5949
# Epoch 33/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6747 - mse: 5.6747
# Epoch 34/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5450 - mse: 5.5450
# Epoch 35/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6824 - mse: 5.6824
# Epoch 36/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6165 - mse: 5.6165
# Epoch 37/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6034 - mse: 5.6034
# Epoch 38/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5817 - mse: 5.5817
# Epoch 39/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5746 - mse: 5.5746
# Epoch 40/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6767 - mse: 5.6767
# Epoch 41/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6228 - mse: 5.6228
# Epoch 42/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6096 - mse: 5.6096
# Epoch 43/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.7022 - mse: 5.7022
# Epoch 44/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6488 - mse: 5.6488
# Epoch 45/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5844 - mse: 5.5844
# Epoch 46/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5795 - mse: 5.5795
# Epoch 47/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5886 - mse: 5.5886
# Epoch 48/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6082 - mse: 5.6082
# Epoch 49/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6773 - mse: 5.6773
# Epoch 50/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5525 - mse: 5.5525
# Epoch 51/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6312 - mse: 5.6312
# Epoch 52/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.4998 - mse: 5.4998
# Epoch 53/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5698 - mse: 5.5698
# Epoch 54/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6414 - mse: 5.6414
# Epoch 55/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6904 - mse: 5.6904
# Epoch 56/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5946 - mse: 5.5946
# Epoch 57/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5552 - mse: 5.5552
# Epoch 58/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6485 - mse: 5.6485
# Epoch 59/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5678 - mse: 5.5678
# Epoch 60/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6710 - mse: 5.6710
# Epoch 61/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5985 - mse: 5.5985
# Epoch 62/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5788 - mse: 5.5788
# Epoch 63/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6294 - mse: 5.6294
# Epoch 64/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5840 - mse: 5.5840
# Epoch 65/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5633 - mse: 5.5633
# Epoch 66/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5036 - mse: 5.5036
# Epoch 67/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5867 - mse: 5.5867
# Epoch 68/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5939 - mse: 5.5939
# Epoch 69/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6072 - mse: 5.6072
# Epoch 70/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6068 - mse: 5.6068
# Epoch 71/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5854 - mse: 5.5854
# Epoch 72/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5618 - mse: 5.5618
# Epoch 73/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5814 - mse: 5.5814
# Epoch 74/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5412 - mse: 5.5412
# Epoch 75/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5270 - mse: 5.5270
# Epoch 76/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6251 - mse: 5.6251
# Epoch 77/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.4735 - mse: 5.4735
# Epoch 78/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6116 - mse: 5.6116
# Epoch 79/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6337 - mse: 5.6337
# Epoch 80/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6835 - mse: 5.6835
# Epoch 81/100
# 364/364 [==============================] - 2s 6ms/step - loss: 5.5480 - mse: 5.5480
# Epoch 82/100
# 364/364 [==============================] - 2s 6ms/step - loss: 5.6296 - mse: 5.6296
# Epoch 83/100
# 364/364 [==============================] - 2s 6ms/step - loss: 5.7476 - mse: 5.7476
# Epoch 84/100
# 364/364 [==============================] - 2s 6ms/step - loss: 5.6235 - mse: 5.6235
# Epoch 85/100
# 364/364 [==============================] - 2s 6ms/step - loss: 5.6475 - mse: 5.6475
# Epoch 86/100
# 364/364 [==============================] - 2s 6ms/step - loss: 5.5612 - mse: 5.5612
# Epoch 87/100
# 364/364 [==============================] - 2s 6ms/step - loss: 5.5211 - mse: 5.5211
# Epoch 88/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5987 - mse: 5.5987
# Epoch 89/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5074 - mse: 5.5074
# Epoch 90/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5950 - mse: 5.5950
# Epoch 91/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6920 - mse: 5.6920
# Epoch 92/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5887 - mse: 5.5887
# Epoch 93/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6897 - mse: 5.6897
# Epoch 94/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6804 - mse: 5.6804
# Epoch 95/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5386 - mse: 5.5386
# Epoch 96/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6430 - mse: 5.6430
# Epoch 97/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5916 - mse: 5.5916
# Epoch 98/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5945 - mse: 5.5945
# Epoch 99/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6483 - mse: 5.6483
# Epoch 100/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5847 - mse: 5.5847
# Iteration  2
# Epoch 1/100
# 364/364 [==============================] - 3s 5ms/step - loss: 36585129823646512.0000 - mse: 36585129823646512.0000
# Epoch 2/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5423 - mse: 5.5423
# Epoch 3/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5613 - mse: 5.5613
# Epoch 4/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6022 - mse: 5.6022
# Epoch 5/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6242 - mse: 5.6242
# Epoch 6/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6069 - mse: 5.6069
# Epoch 7/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5724 - mse: 5.5724
# Epoch 8/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.7185 - mse: 5.7185
# Epoch 9/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6287 - mse: 5.6287
# Epoch 10/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6569 - mse: 5.6569
# Epoch 11/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5943 - mse: 5.5943
# Epoch 12/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6258 - mse: 5.6258
# Epoch 13/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5691 - mse: 5.5691
# Epoch 14/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6617 - mse: 5.6617
# Epoch 15/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6052 - mse: 5.6052
# Epoch 16/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6145 - mse: 5.6145
# Epoch 17/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6521 - mse: 5.6521
# Epoch 18/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5826 - mse: 5.5826
# Epoch 19/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.4781 - mse: 5.4781
# Epoch 20/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6259 - mse: 5.6259
# Epoch 21/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6037 - mse: 5.6037
# Epoch 22/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5013 - mse: 5.5013
# Epoch 23/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6150 - mse: 5.6150
# Epoch 24/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5585 - mse: 5.5585
# Epoch 25/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6820 - mse: 5.6820
# Epoch 26/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6166 - mse: 5.6166
# Epoch 27/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6082 - mse: 5.6082
# Epoch 28/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5816 - mse: 5.5816
# Epoch 29/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6690 - mse: 5.6690
# Epoch 30/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5896 - mse: 5.5896
# Epoch 31/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5602 - mse: 5.5602
# Epoch 32/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6936 - mse: 5.6936
# Epoch 33/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5758 - mse: 5.5758
# Epoch 34/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5021 - mse: 5.5021
# Epoch 35/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.4551 - mse: 5.4551
# Epoch 36/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5610 - mse: 5.5610
# Epoch 37/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5708 - mse: 5.5708
# Epoch 38/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6065 - mse: 5.6065
# Epoch 39/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5620 - mse: 5.5620
# Epoch 40/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5669 - mse: 5.5669
# Epoch 41/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6379 - mse: 5.6379
# Epoch 42/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6541 - mse: 5.6541
# Epoch 43/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6101 - mse: 5.6101
# Epoch 44/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6145 - mse: 5.6145
# Epoch 45/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5721 - mse: 5.5721
# Epoch 46/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5541 - mse: 5.5541
# Epoch 47/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6154 - mse: 5.6154
# Epoch 48/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5682 - mse: 5.5682
# Epoch 49/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6011 - mse: 5.6011
# Epoch 50/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5627 - mse: 5.5627
# Epoch 51/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6950 - mse: 5.6950
# Epoch 52/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6197 - mse: 5.6197
# Epoch 53/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5366 - mse: 5.5366
# Epoch 54/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6679 - mse: 5.6679
# Epoch 55/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6938 - mse: 5.6938
# Epoch 56/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5294 - mse: 5.5294
# Epoch 57/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6006 - mse: 5.6006
# Epoch 58/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6004 - mse: 5.6004
# Epoch 59/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5466 - mse: 5.5466
# Epoch 60/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5709 - mse: 5.5709
# Epoch 61/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6861 - mse: 5.6861
# Epoch 62/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6435 - mse: 5.6435
# Epoch 63/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6147 - mse: 5.6147
# Epoch 64/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6432 - mse: 5.6432
# Epoch 65/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6697 - mse: 5.6697
# Epoch 66/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5756 - mse: 5.5756
# Epoch 67/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6420 - mse: 5.6420
# Epoch 68/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6256 - mse: 5.6256
# Epoch 69/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6331 - mse: 5.6331
# Epoch 70/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6625 - mse: 5.6625
# Epoch 71/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6532 - mse: 5.6532
# Epoch 72/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6273 - mse: 5.6273
# Epoch 73/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5672 - mse: 5.5672
# Epoch 74/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5495 - mse: 5.5495
# Epoch 75/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5704 - mse: 5.5704
# Epoch 76/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6403 - mse: 5.6403
# Epoch 77/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5610 - mse: 5.5610
# Epoch 78/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6067 - mse: 5.6067
# Epoch 79/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5696 - mse: 5.5696
# Epoch 80/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6511 - mse: 5.6511
# Epoch 81/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.7371 - mse: 5.7371
# Epoch 82/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6524 - mse: 5.6524
# Epoch 83/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6616 - mse: 5.6616
# Epoch 84/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5652 - mse: 5.5652
# Epoch 85/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5687 - mse: 5.5687
# Epoch 86/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5970 - mse: 5.5970
# Epoch 87/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5813 - mse: 5.5813
# Epoch 88/100
# 364/364 [==============================] - 2s 6ms/step - loss: 5.6140 - mse: 5.6140
# Epoch 89/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6981 - mse: 5.6981
# Epoch 90/100
# 364/364 [==============================] - 2s 6ms/step - loss: 5.5824 - mse: 5.5824
# Epoch 91/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6361 - mse: 5.6361
# Epoch 92/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5764 - mse: 5.5764
# Epoch 93/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6392 - mse: 5.6392
# Epoch 94/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6336 - mse: 5.6336
# Epoch 95/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6266 - mse: 5.6266
# Epoch 96/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6219 - mse: 5.6219
# Epoch 97/100
# 364/364 [==============================] - 2s 6ms/step - loss: 5.5817 - mse: 5.5817
# Epoch 98/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6261 - mse: 5.6261
# Epoch 99/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6127 - mse: 5.6127
# Epoch 100/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5640 - mse: 5.5640
# Iteration  3
# Epoch 1/100
# 364/364 [==============================] - 3s 5ms/step - loss: 41751568750273344.0000 - mse: 41751571203699864.0000
# Epoch 2/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6021 - mse: 5.6021
# Epoch 3/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5807 - mse: 5.5807
# Epoch 4/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6210 - mse: 5.6210
# Epoch 5/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5636 - mse: 5.5636
# Epoch 6/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6385 - mse: 5.6385
# Epoch 7/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6087 - mse: 5.6087
# Epoch 8/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6785 - mse: 5.6785
# Epoch 9/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6558 - mse: 5.6558
# Epoch 10/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5497 - mse: 5.5497
# Epoch 11/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5576 - mse: 5.5576
# Epoch 12/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5949 - mse: 5.5949
# Epoch 13/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5163 - mse: 5.5163
# Epoch 14/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5919 - mse: 5.5919
# Epoch 15/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5819 - mse: 5.5819
# Epoch 16/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6069 - mse: 5.6069
# Epoch 17/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5456 - mse: 5.5456
# Epoch 18/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6030 - mse: 5.6030
# Epoch 19/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5245 - mse: 5.5245
# Epoch 20/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6405 - mse: 5.6405
# Epoch 21/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5535 - mse: 5.5535
# Epoch 22/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.4598 - mse: 5.4598
# Epoch 23/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6499 - mse: 5.6499
# Epoch 24/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6010 - mse: 5.6010
# Epoch 25/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6079 - mse: 5.6079
# Epoch 26/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6038 - mse: 5.6038
# Epoch 27/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5654 - mse: 5.5654
# Epoch 28/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5866 - mse: 5.5866
# Epoch 29/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6101 - mse: 5.6101
# Epoch 30/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6653 - mse: 5.6653
# Epoch 31/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6500 - mse: 5.6500
# Epoch 32/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6350 - mse: 5.6350
# Epoch 33/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5219 - mse: 5.5219
# Epoch 34/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5621 - mse: 5.5621
# Epoch 35/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5953 - mse: 5.5953
# Epoch 36/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6560 - mse: 5.6560
# Epoch 37/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5310 - mse: 5.5310
# Epoch 38/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6038 - mse: 5.6038
# Epoch 39/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5938 - mse: 5.5938
# Epoch 40/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5888 - mse: 5.5888
# Epoch 41/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5327 - mse: 5.5327
# Epoch 42/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5808 - mse: 5.5808
# Epoch 43/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6125 - mse: 5.6125
# Epoch 44/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6390 - mse: 5.6390
# Epoch 45/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6103 - mse: 5.6103
# Epoch 46/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5174 - mse: 5.5174
# Epoch 47/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5203 - mse: 5.5203
# Epoch 48/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6441 - mse: 5.6441
# Epoch 49/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5448 - mse: 5.5448
# Epoch 50/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6002 - mse: 5.6002
# Epoch 51/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6220 - mse: 5.6220
# Epoch 52/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5400 - mse: 5.5400
# Epoch 53/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5295 - mse: 5.5295
# Epoch 54/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6022 - mse: 5.6022
# Epoch 55/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6260 - mse: 5.6260
# Epoch 56/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6379 - mse: 5.6379
# Epoch 57/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6220 - mse: 5.6220
# Epoch 58/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6235 - mse: 5.6235
# Epoch 59/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6541 - mse: 5.6541
# Epoch 60/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5882 - mse: 5.5882
# Epoch 61/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5185 - mse: 5.5185
# Epoch 62/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.7072 - mse: 5.7072
# Epoch 63/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6375 - mse: 5.6375
# Epoch 64/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.4950 - mse: 5.4950
# Epoch 65/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6978 - mse: 5.6978
# Epoch 66/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5738 - mse: 5.5738
# Epoch 67/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6188 - mse: 5.6188
# Epoch 68/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5320 - mse: 5.5320
# Epoch 69/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5752 - mse: 5.5752
# Epoch 70/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6325 - mse: 5.6325
# Epoch 71/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5918 - mse: 5.5918
# Epoch 72/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5684 - mse: 5.5684
# Epoch 73/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6081 - mse: 5.6081
# Epoch 74/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5743 - mse: 5.5743
# Epoch 75/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6003 - mse: 5.6003
# Epoch 76/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6120 - mse: 5.6120
# Epoch 77/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5840 - mse: 5.5840
# Epoch 78/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.4851 - mse: 5.4851
# Epoch 79/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5242 - mse: 5.5242
# Epoch 80/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5895 - mse: 5.5895
# Epoch 81/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5326 - mse: 5.5326
# Epoch 82/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5496 - mse: 5.5496
# Epoch 83/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5679 - mse: 5.5679
# Epoch 84/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5865 - mse: 5.5865
# Epoch 85/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5531 - mse: 5.5531
# Epoch 86/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6177 - mse: 5.6177
# Epoch 87/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5472 - mse: 5.5472
# Epoch 88/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5189 - mse: 5.5189
# Epoch 89/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5601 - mse: 5.5601
# Epoch 90/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5745 - mse: 5.5745
# Epoch 91/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6097 - mse: 5.6097
# Epoch 92/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6240 - mse: 5.6240
# Epoch 93/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5124 - mse: 5.5124
# Epoch 94/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6347 - mse: 5.6347
# Epoch 95/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6004 - mse: 5.6004
# Epoch 96/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5749 - mse: 5.5749
# Epoch 97/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6216 - mse: 5.6216
# Epoch 98/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5802 - mse: 5.5802
# Epoch 99/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5941 - mse: 5.5941
# Epoch 100/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5493 - mse: 5.5493
# Iteration  4
# Epoch 1/100
# 364/364 [==============================] - 3s 6ms/step - loss: 2.5640 - mse: 2.5640
# Epoch 2/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.0238 - mse: 1.0238
# Epoch 3/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.9666 - mse: 0.9666
# Epoch 4/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.8885 - mse: 0.8885
# Epoch 5/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.8763 - mse: 0.8763
# Epoch 6/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.7894 - mse: 0.7894
# Epoch 7/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.7612 - mse: 0.7612
# Epoch 8/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.7154 - mse: 0.7154
# Epoch 9/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.6231 - mse: 0.6231
# Epoch 10/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.5697 - mse: 0.5697
# Epoch 11/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.5988 - mse: 0.5988
# Epoch 12/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.5464 - mse: 0.5464
# Epoch 13/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.6423 - mse: 0.6423
# Epoch 14/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3665 - mse: 1.3665
# Epoch 15/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3187 - mse: 1.3187
# Epoch 16/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3230 - mse: 1.3230
# Epoch 17/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3356 - mse: 1.3356
# Epoch 18/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3231 - mse: 1.3231
# Epoch 19/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3325 - mse: 1.3325
# Epoch 20/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3283 - mse: 1.3283
# Epoch 21/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3320 - mse: 1.3320
# Epoch 22/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3314 - mse: 1.3314
# Epoch 23/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3190 - mse: 1.3190
# Epoch 24/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3410 - mse: 1.3410
# Epoch 25/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3179 - mse: 1.3179
# Epoch 26/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3205 - mse: 1.3205
# Epoch 27/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3287 - mse: 1.3287
# Epoch 28/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3357 - mse: 1.3357
# Epoch 29/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3315 - mse: 1.3315
# Epoch 30/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3363 - mse: 1.3363
# Epoch 31/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3277 - mse: 1.3277
# Epoch 32/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3505 - mse: 1.3505
# Epoch 33/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3535 - mse: 1.3535
# Epoch 34/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3095 - mse: 1.3095
# Epoch 35/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3319 - mse: 1.3319
# Epoch 36/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3291 - mse: 1.3291
# Epoch 37/100
# 364/364 [==============================] - 2s 7ms/step - loss: 1.3813 - mse: 1.3813
# Epoch 38/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3334 - mse: 1.3334
# Epoch 39/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3460 - mse: 1.3460
# Epoch 40/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3435 - mse: 1.3435
# Epoch 41/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3127 - mse: 1.3127
# Epoch 42/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3130 - mse: 1.3130
# Epoch 43/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3499 - mse: 1.3499
# Epoch 44/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3243 - mse: 1.3243
# Epoch 45/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3308 - mse: 1.3308
# Epoch 46/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3343 - mse: 1.3343
# Epoch 47/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3178 - mse: 1.3178
# Epoch 48/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3258 - mse: 1.3258
# Epoch 49/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3299 - mse: 1.3299
# Epoch 50/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3454 - mse: 1.3454
# Epoch 51/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3370 - mse: 1.3370
# Epoch 52/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3132 - mse: 1.3132
# Epoch 53/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3402 - mse: 1.3402
# Epoch 54/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3124 - mse: 1.3124
# Epoch 55/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3407 - mse: 1.3407
# Epoch 56/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.2920 - mse: 1.2920
# Epoch 57/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3243 - mse: 1.3243
# Epoch 58/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3521 - mse: 1.3521
# Epoch 59/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3416 - mse: 1.3416
# Epoch 60/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3580 - mse: 1.3580
# Epoch 61/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3499 - mse: 1.3499
# Epoch 62/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3057 - mse: 1.3057
# Epoch 63/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3240 - mse: 1.3240
# Epoch 64/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3270 - mse: 1.3270
# Epoch 65/100
# 364/364 [==============================] - 2s 7ms/step - loss: 1.3299 - mse: 1.3299
# Epoch 66/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3531 - mse: 1.3531
# Epoch 67/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3358 - mse: 1.3358
# Epoch 68/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3622 - mse: 1.3622
# Epoch 69/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3559 - mse: 1.3559
# Epoch 70/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3508 - mse: 1.3508
# Epoch 71/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3250 - mse: 1.3250
# Epoch 72/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3122 - mse: 1.3122
# Epoch 73/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3057 - mse: 1.3057
# Epoch 74/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3578 - mse: 1.3578
# Epoch 75/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3253 - mse: 1.3253
# Epoch 76/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3139 - mse: 1.3139
# Epoch 77/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3245 - mse: 1.3245
# Epoch 78/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3154 - mse: 1.3154
# Epoch 79/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3792 - mse: 1.3792
# Epoch 80/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.2983 - mse: 1.2983
# Epoch 81/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3293 - mse: 1.3293
# Epoch 82/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3430 - mse: 1.3430
# Epoch 83/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3168 - mse: 1.3168
# Epoch 84/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3359 - mse: 1.3359
# Epoch 85/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3233 - mse: 1.3233
# Epoch 86/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3321 - mse: 1.3321
# Epoch 87/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3308 - mse: 1.3308
# Epoch 88/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3091 - mse: 1.3091
# Epoch 89/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3272 - mse: 1.3272
# Epoch 90/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3417 - mse: 1.3417
# Epoch 91/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3203 - mse: 1.3203
# Epoch 92/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.2944 - mse: 1.2944
# Epoch 93/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3475 - mse: 1.3475
# Epoch 94/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3203 - mse: 1.3203
# Epoch 95/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3130 - mse: 1.3130
# Epoch 96/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3180 - mse: 1.3180
# Epoch 97/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3633 - mse: 1.3633
# Epoch 98/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3450 - mse: 1.3450
# Epoch 99/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3504 - mse: 1.3504
# Epoch 100/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.3203 - mse: 1.3203
# Iteration  5
# Epoch 1/100
# 364/364 [==============================] - 4s 6ms/step - loss: 5.5334 - mse: 5.5334
# Epoch 2/100
# 364/364 [==============================] - 2s 6ms/step - loss: 2.3292 - mse: 2.3292
# Epoch 3/100
# 364/364 [==============================] - 2s 6ms/step - loss: 1.0177 - mse: 1.0177
# Epoch 4/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.8904 - mse: 0.8904
# Epoch 5/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.9261 - mse: 0.9261
# Epoch 6/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.9109 - mse: 0.9109
# Epoch 7/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.8656 - mse: 0.8656
# Epoch 8/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.8878 - mse: 0.8878
# Epoch 9/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.8382 - mse: 0.8382
# Epoch 10/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.8263 - mse: 0.8263
# Epoch 11/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.8358 - mse: 0.8358
# Epoch 12/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.8395 - mse: 0.8395
# Epoch 13/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.8140 - mse: 0.8140
# Epoch 14/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.8193 - mse: 0.8193
# Epoch 15/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.8097 - mse: 0.8097
# Epoch 16/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.7992 - mse: 0.7992
# Epoch 17/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.7956 - mse: 0.7956
# Epoch 18/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.7952 - mse: 0.7952
# Epoch 19/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.7989 - mse: 0.7989
# Epoch 20/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.7841 - mse: 0.7841
# Epoch 21/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.7971 - mse: 0.7971
# Epoch 22/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.7690 - mse: 0.7690
# Epoch 23/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.7647 - mse: 0.7647
# Epoch 24/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.7310 - mse: 0.7310
# Epoch 25/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.7631 - mse: 0.7631
# Epoch 26/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.7605 - mse: 0.7605
# Epoch 27/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.7423 - mse: 0.7423
# Epoch 28/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.7304 - mse: 0.7304
# Epoch 29/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.7472 - mse: 0.7472
# Epoch 30/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.7126 - mse: 0.7126
# Epoch 31/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.7326 - mse: 0.7326
# Epoch 32/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.7261 - mse: 0.7261
# Epoch 33/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.7234 - mse: 0.7234
# Epoch 34/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.7214 - mse: 0.7214
# Epoch 35/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.7287 - mse: 0.7287
# Epoch 36/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.7011 - mse: 0.7011
# Epoch 37/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.6914 - mse: 0.6914
# Epoch 38/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.7096 - mse: 0.7096
# Epoch 39/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.6621 - mse: 0.6621
# Epoch 40/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.6808 - mse: 0.6808
# Epoch 41/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.6690 - mse: 0.6690
# Epoch 42/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.6641 - mse: 0.6641
# Epoch 43/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.6255 - mse: 0.6255
# Epoch 44/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.6216 - mse: 0.6216
# Epoch 45/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.6356 - mse: 0.6356
# Epoch 46/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.6428 - mse: 0.6428
# Epoch 47/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.6127 - mse: 0.6127
# Epoch 48/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.6349 - mse: 0.6349
# Epoch 49/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.5868 - mse: 0.5868
# Epoch 50/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.5575 - mse: 0.5575
# Epoch 51/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.5923 - mse: 0.5923
# Epoch 52/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.5768 - mse: 0.5768
# Epoch 53/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.5600 - mse: 0.5600
# Epoch 54/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.5338 - mse: 0.5338
# Epoch 55/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.5343 - mse: 0.5343
# Epoch 56/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.5459 - mse: 0.5459
# Epoch 57/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.5121 - mse: 0.5121
# Epoch 58/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.5360 - mse: 0.5360
# Epoch 59/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.4977 - mse: 0.4977
# Epoch 60/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.5086 - mse: 0.5086
# Epoch 61/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.5130 - mse: 0.5130
# Epoch 62/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.4920 - mse: 0.4920
# Epoch 63/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.4957 - mse: 0.4957
# Epoch 64/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.5094 - mse: 0.5094
# Epoch 65/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.4843 - mse: 0.4843
# Epoch 66/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.4596 - mse: 0.4596
# Epoch 67/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.4600 - mse: 0.4600
# Epoch 68/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.4734 - mse: 0.4734
# Epoch 69/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.4628 - mse: 0.4628
# Epoch 70/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.4494 - mse: 0.4494
# Epoch 71/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.4440 - mse: 0.4440
# Epoch 72/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.4494 - mse: 0.4494
# Epoch 73/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.4501 - mse: 0.4501
# Epoch 74/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.4432 - mse: 0.4432
# Epoch 75/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.4355 - mse: 0.4355
# Epoch 76/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.4548 - mse: 0.4548
# Epoch 77/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.4369 - mse: 0.4369
# Epoch 78/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.4317 - mse: 0.4317
# Epoch 79/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.4454 - mse: 0.4454
# Epoch 80/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.4389 - mse: 0.4389
# Epoch 81/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.4399 - mse: 0.4399
# Epoch 82/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.4553 - mse: 0.4553
# Epoch 83/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.4382 - mse: 0.4382
# Epoch 84/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.4162 - mse: 0.4162
# Epoch 85/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.4318 - mse: 0.4318
# Epoch 86/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.4750 - mse: 0.4750
# Epoch 87/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.4116 - mse: 0.4116
# Epoch 88/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.4491 - mse: 0.4491
# Epoch 89/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.4557 - mse: 0.4557
# Epoch 90/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.4391 - mse: 0.4391
# Epoch 91/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.4241 - mse: 0.4241
# Epoch 92/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.4437 - mse: 0.4437
# Epoch 93/100
# 364/364 [==============================] - 2s 6ms/step - loss: 0.4386 - mse: 0.4386
# Epoch 94/100
# ...
# Epoch 37/100
# 364/364 [==============================] - 1s 4ms/step - loss: 5.6604 - mse: 5.6604
# Epoch 38/100
# 364/364 [==============================] - 1s 4ms/step - loss: 5.5478 - mse: 5.5478
# Epoch 39/100
# 364/364 [==============================] - 1s 4ms/step - loss: 5.6001 - mse: 5.6001
# Epoch 40/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.5985 - mse: 5.5985
# Epoch 41/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.5914 - mse: 5.5914
# Epoch 42/100
# 364/364 [==============================] - 1s 4ms/step - loss: 5.6066 - mse: 5.6066
# Epoch 43/100
# 364/364 [==============================] - 1s 4ms/step - loss: 5.5272 - mse: 5.5272
# Epoch 44/100
# 364/364 [==============================] - 1s 4ms/step - loss: 5.5525 - mse: 5.5525
# Epoch 45/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.6317 - mse: 5.6317
# Epoch 46/100
# 364/364 [==============================] - 1s 4ms/step - loss: 5.5586 - mse: 5.5586
# Epoch 47/100
# 364/364 [==============================] - 1s 4ms/step - loss: 5.6599 - mse: 5.6599
# Epoch 48/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.6184 - mse: 5.6184
# Epoch 49/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.6477 - mse: 5.6477
# Epoch 50/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.6665 - mse: 5.6665
# Epoch 51/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.6093 - mse: 5.6093
# Epoch 52/100
# 364/364 [==============================] - 1s 4ms/step - loss: 5.5355 - mse: 5.5355
# Epoch 53/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.6058 - mse: 5.6058
# Epoch 54/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.6367 - mse: 5.6367
# Epoch 55/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.5930 - mse: 5.5930
# Epoch 56/100
# 364/364 [==============================] - 1s 4ms/step - loss: 5.6000 - mse: 5.6000
# Epoch 57/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.6107 - mse: 5.6107
# Epoch 58/100
# 364/364 [==============================] - 1s 4ms/step - loss: 5.5515 - mse: 5.5515
# Epoch 59/100
# 364/364 [==============================] - 1s 4ms/step - loss: 5.5676 - mse: 5.5676
# Epoch 60/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.6125 - mse: 5.6125
# Epoch 61/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.5625 - mse: 5.5625
# Epoch 62/100
# 364/364 [==============================] - 1s 4ms/step - loss: 5.6296 - mse: 5.6296
# Epoch 63/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.7435 - mse: 5.7435
# Epoch 64/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.5459 - mse: 5.5459
# Epoch 65/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.6461 - mse: 5.6461
# Epoch 66/100
# 364/364 [==============================] - 1s 4ms/step - loss: 5.5609 - mse: 5.5609
# Epoch 67/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.6655 - mse: 5.6655
# Epoch 68/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.6546 - mse: 5.6546
# Epoch 69/100
# 364/364 [==============================] - 1s 4ms/step - loss: 5.6027 - mse: 5.6027
# Epoch 70/100
# 364/364 [==============================] - 1s 4ms/step - loss: 5.5450 - mse: 5.5450
# Epoch 71/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.6627 - mse: 5.6627
# Epoch 72/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.6929 - mse: 5.6929
# Epoch 73/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.6037 - mse: 5.6037
# Epoch 74/100
# 364/364 [==============================] - 1s 4ms/step - loss: 5.5974 - mse: 5.5974
# Epoch 75/100
# 364/364 [==============================] - 1s 4ms/step - loss: 5.6296 - mse: 5.6296
# Epoch 76/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.5436 - mse: 5.5436
# Epoch 77/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.4808 - mse: 5.4808
# Epoch 78/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.5196 - mse: 5.5196
# Epoch 79/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.5996 - mse: 5.5996
# Epoch 80/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.5083 - mse: 5.5083
# Epoch 81/100
# 364/364 [==============================] - 1s 4ms/step - loss: 5.5967 - mse: 5.5967
# Epoch 82/100
# 364/364 [==============================] - 1s 4ms/step - loss: 5.5346 - mse: 5.5346
# Epoch 83/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.6316 - mse: 5.6316
# Epoch 84/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.5625 - mse: 5.5625
# Epoch 85/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.5430 - mse: 5.5430
# Epoch 86/100
# 364/364 [==============================] - 1s 4ms/step - loss: 5.6024 - mse: 5.6024
# Epoch 87/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.6024 - mse: 5.6024
# Epoch 88/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.5954 - mse: 5.5954
# Epoch 89/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.6416 - mse: 5.6416
# Epoch 90/100
# 364/364 [==============================] - 1s 4ms/step - loss: 5.5645 - mse: 5.5645
# Epoch 91/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.5623 - mse: 5.5623
# Epoch 92/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.5421 - mse: 5.5421
# Epoch 93/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.6010 - mse: 5.6010
# Epoch 94/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.5169 - mse: 5.5169
# Epoch 95/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.5432 - mse: 5.5432
# Epoch 96/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.6017 - mse: 5.6017
# Epoch 97/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.5509 - mse: 5.5509
# Epoch 98/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.5741 - mse: 5.5741
# Epoch 99/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.5587 - mse: 5.5587
# Epoch 100/100
# 364/364 [==============================] - 2s 4ms/step - loss: 5.6026 - mse: 5.6026
# Iteration  20
# Epoch 1/100
# 364/364 [==============================] - 3s 5ms/step - loss: 108664956933162.1094 - mse: 108664956933162.1094
# Epoch 2/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6618 - mse: 5.6618
# Epoch 3/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5651 - mse: 5.5651
# Epoch 4/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6684 - mse: 5.6684
# Epoch 5/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5516 - mse: 5.5516
# Epoch 6/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6220 - mse: 5.6220
# Epoch 7/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5979 - mse: 5.5979
# Epoch 8/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5137 - mse: 5.5137
# Epoch 9/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6562 - mse: 5.6562
# Epoch 10/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5961 - mse: 5.5961
# Epoch 11/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6765 - mse: 5.6765
# Epoch 12/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5660 - mse: 5.5660
# Epoch 13/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5711 - mse: 5.5711
# Epoch 14/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.7024 - mse: 5.7024
# Epoch 15/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.4768 - mse: 5.4768
# Epoch 16/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6217 - mse: 5.6217
# Epoch 17/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5694 - mse: 5.5694
# Epoch 18/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6856 - mse: 5.6856
# Epoch 19/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5454 - mse: 5.5454
# Epoch 20/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5478 - mse: 5.5478
# Epoch 21/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5483 - mse: 5.5483
# Epoch 22/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6046 - mse: 5.6046
# Epoch 23/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6104 - mse: 5.6104
# Epoch 24/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5815 - mse: 5.5815
# Epoch 25/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6423 - mse: 5.6423
# Epoch 26/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6926 - mse: 5.6926
# Epoch 27/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6092 - mse: 5.6092
# Epoch 28/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6569 - mse: 5.6569
# Epoch 29/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6772 - mse: 5.6772
# Epoch 30/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.4857 - mse: 5.4857
# Epoch 31/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6369 - mse: 5.6369
# Epoch 32/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5865 - mse: 5.5865
# Epoch 33/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5711 - mse: 5.5711
# Epoch 34/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6374 - mse: 5.6374
# Epoch 35/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5745 - mse: 5.5745
# Epoch 36/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6147 - mse: 5.6147
# Epoch 37/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5911 - mse: 5.5911
# Epoch 38/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.4760 - mse: 5.4760
# Epoch 39/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6150 - mse: 5.6150
# Epoch 40/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6788 - mse: 5.6788
# Epoch 41/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5895 - mse: 5.5895
# Epoch 42/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5919 - mse: 5.5919
# Epoch 43/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5938 - mse: 5.5938
# Epoch 44/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5416 - mse: 5.5416
# Epoch 45/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6343 - mse: 5.6343
# Epoch 46/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6053 - mse: 5.6053
# Epoch 47/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6655 - mse: 5.6655
# Epoch 48/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6057 - mse: 5.6057
# Epoch 49/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6905 - mse: 5.6905
# Epoch 50/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6027 - mse: 5.6027
# Epoch 51/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6699 - mse: 5.6699
# Epoch 52/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6068 - mse: 5.6068
# Epoch 53/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6851 - mse: 5.6851
# Epoch 54/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6613 - mse: 5.6613
# Epoch 55/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5859 - mse: 5.5859
# Epoch 56/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5368 - mse: 5.5368
# Epoch 57/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5967 - mse: 5.5967
# Epoch 58/100
# 364/364 [==============================] - 2s 6ms/step - loss: 5.5006 - mse: 5.5006
# Epoch 59/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6200 - mse: 5.6200
# Epoch 60/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5979 - mse: 5.5979
# Epoch 61/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6789 - mse: 5.6789
# Epoch 62/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6522 - mse: 5.6522
# Epoch 63/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5614 - mse: 5.5614
# Epoch 64/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6831 - mse: 5.6831
# Epoch 65/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6845 - mse: 5.6845
# Epoch 66/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.4675 - mse: 5.4675
# Epoch 67/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6484 - mse: 5.6484
# Epoch 68/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6232 - mse: 5.6232
# Epoch 69/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6961 - mse: 5.6961
# Epoch 70/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6141 - mse: 5.6141
# Epoch 71/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6211 - mse: 5.6211
# Epoch 72/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.4871 - mse: 5.4871
# Epoch 73/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5921 - mse: 5.5921
# Epoch 74/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5627 - mse: 5.5627
# Epoch 75/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6362 - mse: 5.6362
# Epoch 76/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5429 - mse: 5.5429
# Epoch 77/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.7025 - mse: 5.7025
# Epoch 78/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5131 - mse: 5.5131
# Epoch 79/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5653 - mse: 5.5653
# Epoch 80/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6099 - mse: 5.6099
# Epoch 81/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6504 - mse: 5.6504
# Epoch 82/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5634 - mse: 5.5634
# Epoch 83/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5985 - mse: 5.5985
# Epoch 84/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5662 - mse: 5.5662
# Epoch 85/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5930 - mse: 5.5930
# Epoch 86/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5643 - mse: 5.5643
# Epoch 87/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6140 - mse: 5.6140
# Epoch 88/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5679 - mse: 5.5679
# Epoch 89/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.4994 - mse: 5.4994
# Epoch 90/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6079 - mse: 5.6079
# Epoch 91/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5336 - mse: 5.5336
# Epoch 92/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6385 - mse: 5.6385
# Epoch 93/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5541 - mse: 5.5541
# Epoch 94/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6650 - mse: 5.6650
# Epoch 95/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6439 - mse: 5.6439
# Epoch 96/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5824 - mse: 5.5824
# Epoch 97/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6207 - mse: 5.6207
# Epoch 98/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6333 - mse: 5.6333
# Epoch 99/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.5485 - mse: 5.5485
# Epoch 100/100
# 364/364 [==============================] - 2s 5ms/step - loss: 5.6587 - mse: 5.6587

# %% [markdown]
# We now process the models obtained in the previous step and select the one with the minimum MSE.

# %%
min = 99999
min_i = 0

print("Number of models tried:", len(mseSumList))

for i in range(len(mseSumList)) :
  if mseSumList[i] < min :
    min = mseSumList[i]
    min_i = i

print("The minimum MSE error on the test data is :-",min)
print("The number of layers are :-",paramsList[min_i][0])
print("Number of neutrons per layer are :- ",paramsList[min_i][1])
print("Activation Function Used :- ",paramsList[min_i][2])
print("Learning rate is :-",paramsList[min_i][3])
# Out:
# Number of models tried: 20
# The minimum MSE error on the test data is :- 0.3811634
# The number of layers are :- 22
# Number of neutrons per layer are :-  [239, 350, 417, 461, 328, 787, 318, 488, 725, 646, 883, 419, 983, 29, 113, 647, 345, 207, 392, 571, 478, 528]
# Activation Function Used :-  relu
# Learning rate is :- 0.0001

# %% [markdown]
# Printing a summary of the Best Model

# %%
modelList[min_i].summary()
# Out:
# Model: "sequential_33"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_723 (Dense)            (None, 239)               3107
# _________________________________________________________________
# dense_724 (Dense)            (None, 350)               84000
# _________________________________________________________________
# dense_725 (Dense)            (None, 417)               146367
# _________________________________________________________________
# dense_726 (Dense)            (None, 461)               192698
# _________________________________________________________________
# dense_727 (Dense)            (None, 328)               151536
# _________________________________________________________________
# dense_728 (Dense)            (None, 787)               258923
# _________________________________________________________________
# dense_729 (Dense)            (None, 318)               250584
# _________________________________________________________________
# dense_730 (Dense)            (None, 488)               155672
# _________________________________________________________________
# dense_731 (Dense)            (None, 725)               354525
# _________________________________________________________________
# dense_732 (Dense)            (None, 646)               468996
# _________________________________________________________________
# dense_733 (Dense)            (None, 883)               571301
# _________________________________________________________________
# dense_734 (Dense)            (None, 419)               370396
# _________________________________________________________________
# dense_735 (Dense)            (None, 983)               412860
# _________________________________________________________________
# dense_736 (Dense)            (None, 29)                28536
# _________________________________________________________________
# dense_737 (Dense)            (None, 113)               3390
# _________________________________________________________________
# dense_738 (Dense)            (None, 647)               73758
# _________________________________________________________________
# dense_739 (Dense)            (None, 345)               223560
# _________________________________________________________________
# dense_740 (Dense)            (None, 207)               71622
# _________________________________________________________________
# dense_741 (Dense)            (None, 392)               81536
# _________________________________________________________________
# dense_742 (Dense)            (None, 571)               224403
# _________________________________________________________________
# dense_743 (Dense)            (None, 478)               273416
# _________________________________________________________________
# dense_744 (Dense)            (None, 528)               252912
# _________________________________________________________________
# dense_745 (Dense)            (None, 1)                 529
# =================================================================
# Total params: 4,654,627
# Trainable params: 4,654,627
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Printing all the Random Parameters generated, along with their errors. And show the top 5 set of parameters

# %%
def Extract(lst,i):
    return [item[i] for item in lst]

mseSumList = Extract(mseSumList,0)  
b = Extract(paramsList,0)
c = Extract(paramsList,1)
d = Extract(paramsList,2)
e = Extract(paramsList,3)

# %%
tempList = []
for i in mseSumList :
  tempList.append(i)
tempList.sort()
rankList = [None]*n_iter
for i in range(n_iter) :
  for j in range(n_iter) :
    if(tempList[j] == mseSumList[i]) :
      rankList[i] = j+1
      break

# %%
paramData = {
    "Number Of Layers " : b,
    "Neuron/Layer" : c,
    "Activation Fn" : d,
    "Learning Rate" : e ,
    "Mse " : mseSumList,
    "Rank" : rankList
}
dframe = pd.DataFrame(data=paramData)
dframe.to_csv('drive/MyDrive/paramData.csv')
dframe.to_csv('paramData.csv')
dframe.sort_values("Rank").head()
# Out:
#     Number Of Layers   ... Rank
# 12                 22  ...    1
# 7                  12  ...    2
# 6                  26  ...    3
# 4                  29  ...    4
# 13                 26  ...    5
#
# [5 rows x 6 columns]

# %% [markdown]
# ## 3. Result
#
# We obtained the following results after Performing Regression on Housing Prices Dataset using a Deep Neural Network and Optimizing its parameters using a custom implementation of Random Search.
#
# Optimal Parameters were found to be
#
# - Number of layers: 22
# - Number of neurons per layer: [239, 350, 417, 461, 328, 787, 318, 488, 725, 646, 883, 419, 983, 29, 113, 647, 345, 207, 392, 571, 478, 528]
# - Activation Function Used: relu
# - Learning rate: 0.0001
#
# The minimum MSE error obtained on the test data is 0.3811634.
